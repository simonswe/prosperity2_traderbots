# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# generate uniform distribution
n = 100000
x = np.random.uniform(0, 1, n)

# generate reserve prices
a = 1/10000
b = -9/50
c = 81 - x
reserve_prices = (-(b) + np.sqrt(b**2 - 4*a*c)) / (2*a)

# plot histogram
plt.hist(reserve_prices, bins=100, density=True)
plt.show()

# plot scatter plot
plt.scatter(x, reserve_prices, s=0.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
reserve_prices.shape
# Out:
# (100000,)

# %%
reserve_prices
# Out:
# array([949.16985628, 908.6839114 , 973.72969053, ..., 945.29474756,
#        955.77359213, 996.66112313])

# %%
def get_p(avg, h):
    return (1000-avg)/(1000-h)

def decide(rp, l, h):
    if (l >= rp):
        return 1000 - l
    elif (h >= rp):
        if (h < island_avg):
            p = get_p(island_avg, h)
        else:
            p = 1
        return (1000 - h) * p
    else:
        return 0
    

    
island_avg = 999
    
# run some simulations
ls = [952, 933]
hs = [978, 966]
totals = []
for l, h in zip(ls, hs):
    total = 0
    for rp in reserve_prices:
        total += decide(rp, l, h)
    totals.append(total)
print(totals)
# Out:
# [1342194.0, 779175.0]

# %%
# run all simulations
i_no = 0
all_totals = {}
max_total = 0
for l in range(900, 1000):
    for h in range(l + 1, 1000):
        total = 0
        for rp in reserve_prices:
            total += decide(rp, l, h)
        all_totals[total] = [l, h]
        max_total = max(max_total, total)
        i_no += 1
        if i_no % 200 == 0:
            print(f"i_no: {i_no}, max profit: {max_total}, bids: {all_totals[max_total]}")
print(f"max profit: {max_total}, bids: {all_totals[max_total]}")
# Out:
# i_no: 200, max profit: 99304, bids: [901, 999]
# i_no: 400, max profit: 108206, bids: [903, 999]
# i_no: 600, max profit: 120590, bids: [905, 999]
# i_no: 800, max profit: 143110, bids: [907, 999]
# i_no: 1000, max profit: 172280, bids: [909, 999]
# i_no: 1200, max profit: 206819.0, bids: [912, 990]
# i_no: 1400, max profit: 264120, bids: [914, 999]
# i_no: 1600, max profit: 313166, bids: [916, 999]
# i_no: 1800, max profit: 395870, bids: [919, 999]
# i_no: 2000, max profit: 454256, bids: [921, 999]
# i_no: 2200, max profit: 541955, bids: [924, 999]
# i_no: 2400, max profit: 636662, bids: [927, 999]
# i_no: 2600, max profit: 725698.0, bids: [930, 995]
# i_no: 2800, max profit: 823974.0, bids: [933, 994]
# i_no: 3000, max profit: 930890, bids: [936, 999]
# i_no: 3200, max profit: 1020110, bids: [939, 999]
# i_no: 3400, max profit: 1125118.0, bids: [943, 989]
# i_no: 3600, max profit: 1228255, bids: [946, 999]
# i_no: 3800, max profit: 1333516, bids: [950, 999]
# i_no: 4000, max profit: 1429681.0, bids: [955, 995]
# i_no: 4200, max profit: 1495710, bids: [959, 999]
# i_no: 4400, max profit: 1538814, bids: [965, 999]
# i_no: 4600, max profit: 1539173, bids: [966, 999]
# i_no: 4800, max profit: 1539173, bids: [966, 999]
# max profit: 1539173, bids: [966, 999]
