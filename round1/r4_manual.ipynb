# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# generate uniform distribution
n = 100000
x = np.random.uniform(0, 1, n)

# generate reserve prices
a = 1/10000
b = -9/50
c = 81 - x
reserve_prices = (-(b) + np.sqrt(b**2 - 4*a*c)) / (2*a)

# plot histogram
plt.hist(reserve_prices, bins=100, density=True)
plt.show()

# plot scatter plot
plt.scatter(x, reserve_prices, s=0.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
reserve_prices.shape
# Out:
# (100000,)

# %%
reserve_prices
# Out:
# array([949.5235449 , 974.084915  , 953.23445521, ..., 960.77362567,
#        971.21176742, 978.01140629])

# %%
def get_p(avg, h):
    return (1000-avg)/(1000-h)
island_avg = 985
def decide(rp, l, h):
    if (l >= rp):
        return 1000 - l
    elif (h >= rp):
        if (h < island_avg):
            p = get_p(island_avg, h)
        else:
            p = 1
        return (1000 - h) * p
    else:
        return 0
    
    
# run some simulations
ls = [952, 933]
hs = [978, 966]
totals = []
for l, h in zip(ls, hs):
    total = 0
    for rp in reserve_prices:
        total += decide(rp, l, h)
    totals.append(total)
print(totals)
# Out:
# [1802181.0, 1215934.0]

# %%
# run all simulations
i_no = 0
all_totals = {}
max_total = 0
for l in range(900, 1000):
    for h in range(l + 1, 1000):
        total = 0
        for rp in reserve_prices:
            total += decide(rp, l, h)
        all_totals[total] = [l, h]
        max_total = max(max_total, total)
        i_no += 1
        if i_no % 200 == 0:
            print(f"i_no: {i_no}, max profit: {max_total}, bids: {all_totals[max_total]}")
print(f"max profit: {max_total}, bids: {all_totals[max_total]}")
# Out:
# i_no: 200, max profit: 1084248, bids: [901, 985]
# i_no: 400, max profit: 1090784, bids: [903, 985]
# i_no: 600, max profit: 1104600, bids: [905, 985]
# i_no: 800, max profit: 1121772, bids: [907, 985]
# i_no: 1000, max profit: 1145180, bids: [909, 985]
# i_no: 1200, max profit: 1186389, bids: [912, 985]
# i_no: 1400, max profit: 1222258, bids: [914, 985]
# i_no: 1600, max profit: 1257120, bids: [916, 985]
# i_no: 1800, max profit: 1317540, bids: [919, 985]
# i_no: 2000, max profit: 1359080, bids: [921, 985]
# i_no: 2200, max profit: 1427280, bids: [924, 985]
# i_no: 2400, max profit: 1500434, bids: [927, 985]
# i_no: 2600, max profit: 1570540, bids: [930, 985]
# i_no: 2800, max profit: 1645204, bids: [933, 985]
# i_no: 3000, max profit: 1713331, bids: [936, 985]
# i_no: 3200, max profit: 1778116, bids: [939, 985]
# i_no: 3400, max profit: 1856166, bids: [943, 985]
# i_no: 3600, max profit: 1904619, bids: [946, 985]
# i_no: 3800, max profit: 1955825, bids: [950, 985]
# i_no: 4000, max profit: 1992270, bids: [955, 985]
# i_no: 4200, max profit: 1994304, bids: [957, 985]
# i_no: 4400, max profit: 1994304, bids: [957, 985]
# i_no: 4600, max profit: 1994304, bids: [957, 985]
# i_no: 4800, max profit: 1994304, bids: [957, 985]
# max profit: 1994304, bids: [957, 985]
